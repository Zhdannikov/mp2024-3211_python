# %% [markdown]
# # Удалить фон изображения

# %%
# pip install rembg

# %%
from rembg import remove
from PIL import Image

# %%
Image.open('car.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x1000>

# %%
remove(Image.open('car.png'))
# Out:
# ...
# 100%|###############################################| 176M/176M [00:00<?, ?B/s]
# <PIL.Image.Image image mode=RGBA size=1600x1000>
